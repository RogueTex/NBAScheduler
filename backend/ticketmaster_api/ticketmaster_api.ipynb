# %% [markdown]
# ## Install libraries and packages, API Key

# %%
# !pip install requests
# !pip -q install tqdm
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)

# %%
import pandas as pd
import requests
import json
import re
import time
from datetime import datetime, timedelta
from tqdm import tqdm

# %%
from google.colab import userdata

api_key = userdata.get('ticketmaster')
print("API Key:", api_key)
# Out:
# API Key: C0tz5zkAZbwFEBVugpiRzsDrNNPSp70b

# %% [markdown]
# ## API Call

# %% [markdown]
# ### NBA Arena Coordinates

# %%
# Manually create a dictionary or list of dictionaries with venue names
# The key should be the 'Team' name from the DataFrame, and the value should be the venue name.
venue_names = {
    'Atlanta Hawks': 'State Farm Arena',
    'Boston Celtics': 'TD Garden',
    'Brooklyn Nets': 'Barclays Center',
    'Charlotte Hornets': 'Spectrum Center',
    'Chicago Bulls': 'United Center',
    'Cleveland Cavaliers': 'Rocket Mortgage Fieldhouse',
    'Dallas Mavericks': 'American Airlines Center',
    'Denver Nuggets': 'Ball Arena',
    'Detroit Pistons': 'Little Caesars Arena',
    'Golden State Warriors': 'Chase Center',
    'Houston Rockets': 'Toyota Center',
    'Indiana Pacers': 'Gainbridge Fieldhouse',
    'Los Angeles Clippers': 'Intuit Dome',
    'Los Angeles Lakers': 'Crypto.com Arena',
    'Memphis Grizzlies': 'FedExForum',
    'Miami Heat': 'Kaseya Center',
    'Milwaukee Bucks': 'Fiserv Forum',
    'Minnesota Timberwolves': 'Target Center',
    'New Orleans Pelicans': 'Smoothie King Center',
    'New York Knicks': 'Madison Square Garden',
    'Oklahoma City Thunder': 'Paycom Center',
    'Orlando Magic': 'Kia Center',
    'Philadelphia 76ers': 'Xfinity Mobile Arena',
    'Phoenix Suns': 'PHX Arena',
    'Portland Trail Blazers': 'Moda Center',
    'Sacramento Kings': 'Golden 1 Center',
    'San Antonio Spurs': 'Frost Bank Center',
    'Toronto Raptors': 'Scotiabank Arena',
    'Utah Jazz': 'Delta Center',
    'Washington Wizards': 'Capital One Arena'
}

lat = {
    'Atlanta Hawks': 33.7574,
    'Boston Celtics': 42.3663,
    'Brooklyn Nets': 40.6782,
    'Charlotte Hornets': 35.2232,
    'Chicago Bulls': 41.8819,
    'Cleveland Cavaliers': 41.4967,
    'Dallas Mavericks': 32.7767,
    'Denver Nuggets': 39.7422,
    'Detroit Pistons': 42.3314,
    'Golden State Warriors': 37.7749,
    'Houston Rockets': 29.7419,
    'Indiana Pacers': 39.7684,
    'Los Angeles Clippers': 33.9438,
    'Los Angeles Lakers': 34.0489,
    'Memphis Grizzlies': 35.1495,
    'Miami Heat': 25.7743,
    'Milwaukee Bucks': 43.0389,
    'Minnesota Timberwolves': 44.9793,
    'New Orleans Pelicans': 29.9498,
    'New York Knicks': 40.7537,
    'Oklahoma City Thunder': 35.4676,
    'Orlando Magic': 28.5383,
    'Philadelphia 76ers': 39.9042,
    'Phoenix Suns': 33.4484,
    'Portland Trail Blazers': 45.5152,
    'Sacramento Kings': 38.5766,
    'San Antonio Spurs': 29.4241,
    'Toronto Raptors': 43.6618,
    'Utah Jazz': 40.77,
    'Washington Wizards': 38.8951,
}

long = {    'Atlanta Hawks': -84.3962,
    'Boston Celtics': -71.0636,
    'Brooklyn Nets': -73.9442,
    'Charlotte Hornets': -80.8422,
    'Chicago Bulls': -87.6232,
    'Cleveland Cavaliers': -81.6954,
    'Dallas Mavericks': -96.8032,
    'Denver Nuggets': -104.9923,
    'Detroit Pistons': -83.04,
    'Golden State Warriors': -122.4194,
    'Houston Rockets': -95.3,
    'Indiana Pacers': -86.1581,
    'Los Angeles Clippers':-118.3422,
    'Los Angeles Lakers': -118.2673,
    'Memphis Grizzlies': -90.049,
    'Miami Heat': -80.1937,
    'Milwaukee Bucks': -87.9068,
    'Minnesota Timberwolves': -93.2644,
    'New Orleans Pelicans': -90.0816,
    'New York Knicks': -73.9857,
    'Oklahoma City Thunder': -97.5164,
    'Orlando Magic': -81.3792,
    'Philadelphia 76ers': -75.165,
    'Phoenix Suns': -112.074,
    'Portland Trail Blazers': -122.685,
    'Sacramento Kings': -121.491,
    'San Antonio Spurs': -98.4953,
    'Toronto Raptors': -79.391,
    'Utah Jazz': -111.9,
    'Washington Wizards': -77.0364}

# %%
# Create a list of dictionaries from the venue_names, lat, and long dictionaries
venue_data_list = []
for team in venue_names.keys():
    venue_data_list.append({
        'Team': team,
        'Venue Name': venue_names.get(team),
        'Lat': lat.get(team),
        'Long': long.get(team)
    })

# Create a new DataFrame from the list of dictionaries
venue_info_df = pd.DataFrame(venue_data_list)

# Display the new DataFrame
venue_info_df
# Out:
#                       Team                  Venue Name      Lat      Long
# 0            Atlanta Hawks            State Farm Arena  33.7574  -84.3962
# 1           Boston Celtics                   TD Garden  42.3663  -71.0636
# 2            Brooklyn Nets             Barclays Center  40.6782  -73.9442
# 3        Charlotte Hornets             Spectrum Center  35.2232  -80.8422
# 4            Chicago Bulls               United Center  41.8819  -87.6232
# 5      Cleveland Cavaliers  Rocket Mortgage Fieldhouse  41.4967  -81.6954
# 6         Dallas Mavericks    American Airlines Center  32.7767  -96.8032
# 7           Denver Nuggets                  Ball Arena  39.7422 -104.9923
# 8          Detroit Pistons        Little Caesars Arena  42.3314  -83.0400
# 9    Golden State Warriors                Chase Center  37.7749 -122.4194
# 10         Houston Rockets               Toyota Center  29.7419  -95.3000
# 11          Indiana Pacers       Gainbridge Fieldhouse  39.7684  -86.1581
# 12    Los Angeles Clippers                 Intuit Dome  33.9438 -118.3422
# 13      Los Angeles Lakers            Crypto.com Arena  34.0489 -118.2673
# 14       Memphis Grizzlies                  FedExForum  35.1495  -90.0490
# 15              Miami Heat               Kaseya Center  25.7743  -80.1937
# 16         Milwaukee Bucks                Fiserv Forum  43.0389  -87.9068
# 17  Minnesota Timberwolves               Target Center  44.9793  -93.2644
# 18    New Orleans Pelicans        Smoothie King Center  29.9498  -90.0816
# 19         New York Knicks       Madison Square Garden  40.7537  -73.9857
# 20   Oklahoma City Thunder               Paycom Center  35.4676  -97.5164
# 21           Orlando Magic                  Kia Center  28.5383  -81.3792
# 22      Philadelphia 76ers        Xfinity Mobile Arena  39.9042  -75.1650
# 23            Phoenix Suns                   PHX Arena  33.4484 -112.0740
# 24  Portland Trail Blazers                 Moda Center  45.5152 -122.6850
# 25        Sacramento Kings             Golden 1 Center  38.5766 -121.4910
# 26       San Antonio Spurs           Frost Bank Center  29.4241  -98.4953
# 27         Toronto Raptors            Scotiabank Arena  43.6618  -79.3910
# 28               Utah Jazz                Delta Center  40.7700 -111.9000
# 29      Washington Wizards           Capital One Arena  38.8951  -77.0364

# %% [markdown]
# ### API Call

# %%
def safe_request(url, params, retry_delay=1.5, max_retries=6):
    retries = 0
    while True:
        r = requests.get(url, params=params, timeout=30)
        if r.status_code == 429:
            tqdm.write("429 rate limit — sleeping %.1fs..." % retry_delay)
            time.sleep(retry_delay)
            continue
        if r.status_code in (502, 503, 504):
            if retries >= max_retries:
                tqdm.write(f"Server error {r.status_code} — giving up after {max_retries} retries.")
                return None
            tqdm.write(f"Server error {r.status_code} — retrying in {retry_delay}s...")
            time.sleep(retry_delay)
            retries += 1
            continue
        if r.status_code != 200:
            tqdm.write(f"Error {r.status_code}: {r.text[:300]}")
            return None
        return r

def split_date_range(start_date, end_date, step_days=7):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    ranges = []
    cur = start
    while cur <= end:
        nxt = min(cur + timedelta(days=step_days-1), end)
        ranges.append((cur.strftime("%Y-%m-%d"), nxt.strftime("%Y-%m-%d")))
        cur = nxt + timedelta(days=1)
    return ranges


def fetch_all_events_for_venue(api_key, lat, lon, start_date, end_date, radius=5, size=50, show_pages=True):
    """
    Fetch all events for a (lat,lon) between start_date and end_date (YYYY-MM-DD).
    - Respects Ticketmaster paging cap: if monthly range is too large, auto-splits to weekly.
    - Adds a page progress bar if show_pages=True.
    """
    url = "https://app.ticketmaster.com/discovery/v2/events.json"
    all_events = []
    page = 0
    pbar = None

    while True:
        params = {
            "apikey": api_key,
            "latlong": f"{lat},{lon}",
            "radius": radius,
            "unit": "miles",
            "startDateTime": f"{start_date}T00:00:00Z",
            "endDateTime": f"{end_date}T23:59:59Z",
            "size": size,
            "page": page
        }
        r = safe_request(url, params)
        if r is None:
            break

        data = r.json()
        events = data.get("_embedded", {}).get("events", [])

        # Initialize page progress bar after first response (now we know totalPages)
        page_info = data.get("page", {})
        total_pages = page_info.get("totalPages", 1)

        # If this range is too large for TM cap (page*size < 1000), split to weekly
        if total_pages * size >= 1000:
            tqdm.write(f"Splitting {start_date} → {end_date} into weekly chunks...")
            weekly_events = []
            for s, e in split_date_range(start_date, end_date, step_days=7):
                weekly_events.extend(
                    fetch_all_events_for_venue(api_key, lat, lon, s, e, radius, size, show_pages=False)
                )
            # Close any page bar if created
            if pbar is not None:
                pbar.close()
            return weekly_events

        if show_pages and pbar is None and total_pages > 1:
            pbar = tqdm(total=total_pages, desc=f"Pages {start_date}→{end_date}", leave=False)

        # Collect events
        for e in events:
            all_events.append({
                "name": e.get("name"),
                "date": e.get("dates", {}).get("start", {}).get("localDate"),
                "time": e.get("dates", {}).get("start", {}).get("localTime"),
                "venue": e.get("_embedded", {}).get("venues", [{}])[0].get("name")
            })

        # Progress/update paging
        if page >= total_pages - 1:
            if pbar is not None:
                pbar.update(1)
                pbar.close()
            break
        page += 1
        if pbar is not None:
            pbar.update(1)
        time.sleep(1.2)  # respect spike arrest (one+ second between calls)

    return all_events

# %%
season_start = datetime(2025, 10, 21)
season_end   = datetime(2026, 4, 12)

date_ranges = []
cur = season_start
while cur <= season_end:
    month_end = (datetime(cur.year, cur.month+1, 1) - timedelta(days=1)) if cur.month < 12 else datetime(cur.year, 12, 31)
    end = min(month_end, season_end)
    date_ranges.append((cur.strftime("%Y-%m-%d"), end.strftime("%Y-%m-%d")))
    cur = end + timedelta(days=1)

date_ranges
# Out:
# [('2025-10-21', '2025-10-31'),
#  ('2025-11-01', '2025-11-30'),
#  ('2025-12-01', '2025-12-31'),
#  ('2026-01-01', '2026-01-31'),
#  ('2026-02-01', '2026-02-28'),
#  ('2026-03-01', '2026-03-31'),
#  ('2026-04-01', '2026-04-12')]

# %%
all_events = []

venues_bar = tqdm(total=len(venue_info_df), desc="Venues")
for _, row in venue_info_df.iterrows():
    months_bar = tqdm(total=len(date_ranges), desc=row['Venue Name'], leave=False)
    for start, end in date_ranges:
        # fetch monthly (auto-falls-back to weekly inside if needed)
        events = fetch_all_events_for_venue(api_key, row['Lat'], row['Long'], start, end, size=50, show_pages=True)
        # tag team
        for ev in events:
            ev['team'] = row['Team']
        all_events.extend(events)
        months_bar.update(1)
        time.sleep(1.2)  # small gap between month calls
    months_bar.close()
    venues_bar.update(1)
venues_bar.close()

len(all_events)
# Out:
# Venues:   0%|          | 0/30 [00:00<?, ?it/s]
# State Farm Arena:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.44it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 3/3 [00:02<00:00,  1.03it/s]
#
#
# State Farm Arena:  14%|█▍        | 1/7 [00:02<00:17,  2.99s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/8 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  25%|██▌       | 2/8 [00:01<00:04,  1.39it/s]
#
# Pages 2025-11-01→2025-11-30:  38%|███▊      | 3/8 [00:02<00:04,  1.02it/s]
#
# Pages 2025-11-01→2025-11-30:  50%|█████     | 4/8 [00:04<00:04,  1.13s/it]
#
# Pages 2025-11-01→2025-11-30:  62%|██████▎   | 5/8 [00:05<00:03,  1.21s/it]
#
# Pages 2025-11-01→2025-11-30:  75%|███████▌  | 6/8 [00:06<00:02,  1.26s/it]
#
# Pages 2025-11-01→2025-11-30:  88%|████████▊ | 7/8 [00:08<00:01,  1.29s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 8/8 [00:09<00:00,  1.29s/it]
#
#
# State Farm Arena:  29%|██▊       | 2/7 [00:13<00:38,  7.64s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  40%|████      | 2/5 [00:01<00:02,  1.42it/s]
#
# Pages 2025-12-01→2025-12-31:  60%|██████    | 3/5 [00:02<00:01,  1.03it/s]
#
# Pages 2025-12-01→2025-12-31:  80%|████████  | 4/5 [00:04<00:01,  1.11s/it]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
#
#
# State Farm Arena:  43%|████▎     | 3/7 [00:20<00:28,  7.25s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.51it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 3/3 [00:02<00:00,  1.08it/s]
#
#
# State Farm Arena:  57%|█████▋    | 4/7 [00:24<00:17,  5.96s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28:  67%|██████▋   | 2/3 [00:01<00:00,  1.50it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 3/3 [00:02<00:00,  1.07it/s]
#
#
# State Farm Arena:  71%|███████▏  | 5/7 [00:28<00:10,  5.25s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31:  50%|█████     | 2/4 [00:01<00:01,  1.53it/s]
#
# Pages 2026-03-01→2026-03-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.06it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 4/4 [00:03<00:00,  1.08s/it]
#
#
# State Farm Arena:  86%|████████▌ | 6/7 [00:33<00:05,  5.27s/it]
# State Farm Arena: 100%|██████████| 7/7 [00:35<00:00,  3.99s/it]
# Venues:   3%|▎         | 1/30 [00:36<17:38, 36.52s/it]
# TD Garden:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  50%|█████     | 2/4 [00:01<00:01,  1.47it/s]
#
# Pages 2025-10-21→2025-10-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.05it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 4/4 [00:04<00:00,  1.09s/it]
#
#
# TD Garden:  14%|█▍        | 1/7 [00:04<00:24,  4.15s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/11 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  18%|█▊        | 2/11 [00:01<00:06,  1.46it/s]
#
# Pages 2025-11-01→2025-11-30:  27%|██▋       | 3/11 [00:02<00:07,  1.05it/s]
#
# Pages 2025-11-01→2025-11-30:  36%|███▋      | 4/11 [00:04<00:07,  1.09s/it]
#
# Pages 2025-11-01→2025-11-30:  45%|████▌     | 5/11 [00:05<00:07,  1.17s/it]
#
# Pages 2025-11-01→2025-11-30:  55%|█████▍    | 6/11 [00:06<00:06,  1.30s/it]
#
# Pages 2025-11-01→2025-11-30:  64%|██████▎   | 7/11 [00:08<00:05,  1.37s/it]
#
# Pages 2025-11-01→2025-11-30:  73%|███████▎  | 8/11 [00:09<00:04,  1.36s/it]
#
# Pages 2025-11-01→2025-11-30:  82%|████████▏ | 9/11 [00:11<00:02,  1.35s/it]
#
# Pages 2025-11-01→2025-11-30:  91%|█████████ | 10/11 [00:12<00:01,  1.35s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 11/11 [00:13<00:00,  1.34s/it]
#
#
# TD Garden:  29%|██▊       | 2/7 [00:19<00:52, 10.59s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  33%|███▎      | 2/6 [00:01<00:02,  1.51it/s]
#
# Pages 2025-12-01→2025-12-31:  50%|█████     | 3/6 [00:02<00:02,  1.05it/s]
#
# Pages 2025-12-01→2025-12-31:  67%|██████▋   | 4/6 [00:04<00:02,  1.09s/it]
#
# Pages 2025-12-01→2025-12-31:  83%|████████▎ | 5/6 [00:05<00:01,  1.25s/it]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 6/6 [00:07<00:00,  1.32s/it]
#
#
# TD Garden:  43%|████▎     | 3/7 [00:27<00:38,  9.58s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.50it/s]
#
#
# TD Garden:  57%|█████▋    | 4/7 [00:30<00:20,  6.86s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
#
#
# TD Garden:  71%|███████▏  | 5/7 [00:32<00:10,  5.34s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.50it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 3/3 [00:02<00:00,  1.07it/s]
#
#
# TD Garden:  86%|████████▌ | 6/7 [00:36<00:04,  4.88s/it]
# TD Garden: 100%|██████████| 7/7 [00:38<00:00,  3.72s/it]
# Venues:   7%|▋         | 2/30 [01:16<17:51, 38.27s/it]
# Barclays Center:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  40%|████      | 2/5 [00:01<00:02,  1.49it/s]
#
# Pages 2025-10-21→2025-10-31:  60%|██████    | 3/5 [00:02<00:01,  1.05it/s]
#
# Pages 2025-10-21→2025-10-31:  80%|████████  | 4/5 [00:04<00:01,  1.09s/it]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
#
#
# Barclays Center:  14%|█▍        | 1/7 [00:05<00:33,  5.55s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/13 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  15%|█▌        | 2/13 [00:01<00:07,  1.48it/s]
#
# Pages 2025-11-01→2025-11-30:  23%|██▎       | 3/13 [00:02<00:10,  1.03s/it]
#
# Pages 2025-11-01→2025-11-30:  31%|███       | 4/13 [00:04<00:10,  1.21s/it]
#
# Pages 2025-11-01→2025-11-30:  38%|███▊      | 5/13 [00:05<00:10,  1.27s/it]
#
# Pages 2025-11-01→2025-11-30:  46%|████▌     | 6/13 [00:07<00:09,  1.30s/it]
#
# Pages 2025-11-01→2025-11-30:  54%|█████▍    | 7/13 [00:08<00:07,  1.31s/it]
#
# Pages 2025-11-01→2025-11-30:  62%|██████▏   | 8/13 [00:09<00:06,  1.38s/it]
#
# Pages 2025-11-01→2025-11-30:  69%|██████▉   | 9/13 [00:11<00:05,  1.36s/it]
#
# Pages 2025-11-01→2025-11-30:  77%|███████▋  | 10/13 [00:12<00:04,  1.34s/it]
#
# Pages 2025-11-01→2025-11-30:  85%|████████▍ | 11/13 [00:13<00:02,  1.34s/it]
#
# Pages 2025-11-01→2025-11-30:  92%|█████████▏| 12/13 [00:15<00:01,  1.34s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 13/13 [00:16<00:00,  1.34s/it]
#
#
# Barclays Center:  29%|██▊       | 2/7 [00:23<01:04, 12.86s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/8 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  25%|██▌       | 2/8 [00:01<00:03,  1.50it/s]
#
# Pages 2025-12-01→2025-12-31:  38%|███▊      | 3/8 [00:02<00:04,  1.05it/s]
#
# Pages 2025-12-01→2025-12-31:  50%|█████     | 4/8 [00:04<00:04,  1.10s/it]
#
# Pages 2025-12-01→2025-12-31:  62%|██████▎   | 5/8 [00:05<00:03,  1.20s/it]
#
# Pages 2025-12-01→2025-12-31:  75%|███████▌  | 6/8 [00:06<00:02,  1.24s/it]
#
# Pages 2025-12-01→2025-12-31:  88%|████████▊ | 7/8 [00:08<00:01,  1.27s/it]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 8/8 [00:09<00:00,  1.28s/it]
#
#
# Barclays Center:  43%|████▎     | 3/7 [00:34<00:47, 11.89s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.50it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 3/3 [00:02<00:00,  1.04it/s]
#
#
# Barclays Center:  57%|█████▋    | 4/7 [00:38<00:26,  8.78s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.45it/s]
#
#
# Barclays Center:  71%|███████▏  | 5/7 [00:41<00:13,  6.60s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# Barclays Center:  86%|████████▌ | 6/7 [00:43<00:05,  5.26s/it]
# Barclays Center: 100%|██████████| 7/7 [00:45<00:00,  3.98s/it]
# Venues:  10%|█         | 3/30 [02:02<18:51, 41.90s/it]
# Spectrum Center:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Spectrum Center:  14%|█▍        | 1/7 [00:01<00:09,  1.51s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  50%|█████     | 2/4 [00:01<00:01,  1.24it/s]
#
# Pages 2025-11-01→2025-11-30:  75%|███████▌  | 3/4 [00:02<00:01,  1.03s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 4/4 [00:04<00:00,  1.14s/it]
#
#
# Spectrum Center:  29%|██▊       | 2/7 [00:07<00:19,  3.94s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# Spectrum Center:  43%|████▎     | 3/7 [00:09<00:13,  3.36s/it]
# Spectrum Center:  57%|█████▋    | 4/7 [00:11<00:07,  2.56s/it]
# Spectrum Center:  71%|███████▏  | 5/7 [00:12<00:04,  2.12s/it]
# Spectrum Center:  86%|████████▌ | 6/7 [00:13<00:01,  1.85s/it]
# Spectrum Center: 100%|██████████| 7/7 [00:15<00:00,  1.68s/it]
# Venues:  13%|█▎        | 4/30 [02:18<13:47, 31.81s/it]
# United Center:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  29%|██▊       | 2/7 [00:01<00:03,  1.47it/s]
#
# Pages 2025-10-21→2025-10-31:  43%|████▎     | 3/7 [00:02<00:03,  1.06it/s]
#
# Pages 2025-10-21→2025-10-31:  57%|█████▋    | 4/7 [00:03<00:03,  1.09s/it]
#
# Pages 2025-10-21→2025-10-31:  71%|███████▏  | 5/7 [00:05<00:02,  1.17s/it]
#
# Pages 2025-10-21→2025-10-31:  86%|████████▌ | 6/7 [00:06<00:01,  1.23s/it]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 7/7 [00:07<00:00,  1.26s/it]
#
#
# United Center:  14%|█▍        | 1/7 [00:08<00:48,  8.15s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/12 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  17%|█▋        | 2/12 [00:01<00:06,  1.47it/s]
#
# Pages 2025-11-01→2025-11-30:  25%|██▌       | 3/12 [00:02<00:08,  1.03it/s]
#
# Pages 2025-11-01→2025-11-30:  33%|███▎      | 4/12 [00:04<00:09,  1.18s/it]
#
# Pages 2025-11-01→2025-11-30:  42%|████▏     | 5/12 [00:05<00:08,  1.23s/it]
#
# Pages 2025-11-01→2025-11-30:  50%|█████     | 6/12 [00:06<00:07,  1.26s/it]
#
# Pages 2025-11-01→2025-11-30:  58%|█████▊    | 7/12 [00:08<00:06,  1.30s/it]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 8/12 [00:09<00:05,  1.31s/it]
#
# Pages 2025-11-01→2025-11-30:  75%|███████▌  | 9/12 [00:11<00:03,  1.33s/it]
#
# Pages 2025-11-01→2025-11-30:  83%|████████▎ | 10/12 [00:12<00:02,  1.34s/it]
#
# Pages 2025-11-01→2025-11-30:  92%|█████████▏| 11/12 [00:13<00:01,  1.34s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 12/12 [00:15<00:00,  1.33s/it]
#
#
# United Center:  29%|██▊       | 2/7 [00:24<01:05, 13.13s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/9 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  22%|██▏       | 2/9 [00:01<00:04,  1.45it/s]
#
# Pages 2025-12-01→2025-12-31:  33%|███▎      | 3/9 [00:02<00:05,  1.04it/s]
#
# Pages 2025-12-01→2025-12-31:  44%|████▍     | 4/9 [00:04<00:05,  1.10s/it]
#
# Pages 2025-12-01→2025-12-31:  56%|█████▌    | 5/9 [00:05<00:04,  1.20s/it]
#
# Pages 2025-12-01→2025-12-31:  67%|██████▋   | 6/9 [00:06<00:03,  1.25s/it]
#
# Pages 2025-12-01→2025-12-31:  78%|███████▊  | 7/9 [00:08<00:02,  1.27s/it]
#
# Pages 2025-12-01→2025-12-31:  89%|████████▉ | 8/9 [00:09<00:01,  1.29s/it]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 9/9 [00:10<00:00,  1.29s/it]
#
#
# United Center:  43%|████▎     | 3/7 [00:37<00:50, 12.74s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31:  33%|███▎      | 2/6 [00:01<00:02,  1.48it/s]
#
# Pages 2026-01-01→2026-01-31:  50%|█████     | 3/6 [00:02<00:02,  1.06it/s]
#
# Pages 2026-01-01→2026-01-31:  67%|██████▋   | 4/6 [00:04<00:02,  1.09s/it]
#
# Pages 2026-01-01→2026-01-31:  83%|████████▎ | 5/6 [00:05<00:01,  1.17s/it]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 6/6 [00:06<00:00,  1.22s/it]
#
#
# United Center:  57%|█████▋    | 4/7 [00:45<00:32, 10.93s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28:  50%|█████     | 2/4 [00:01<00:01,  1.49it/s]
#
# Pages 2026-02-01→2026-02-28:  75%|███████▌  | 3/4 [00:02<00:00,  1.07it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 4/4 [00:03<00:00,  1.07s/it]
#
#
# United Center:  71%|███████▏  | 5/7 [00:50<00:17,  8.97s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31:  50%|█████     | 2/4 [00:01<00:01,  1.51it/s]
#
# Pages 2026-03-01→2026-03-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.07it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 4/4 [00:03<00:00,  1.08s/it]
#
#
# United Center:  86%|████████▌ | 6/7 [00:55<00:07,  7.71s/it]
#
# Pages 2026-04-01→2026-04-12:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-04-01→2026-04-12:  67%|██████▋   | 2/3 [00:01<00:00,  1.52it/s]
#
# Pages 2026-04-01→2026-04-12: 100%|██████████| 3/3 [00:02<00:00,  1.08it/s]
#
#
# United Center: 100%|██████████| 7/7 [00:59<00:00,  6.48s/it]
# Venues:  17%|█▋        | 5/30 [03:19<17:39, 42.38s/it]
# Rocket Mortgage Fieldhouse:   0%|          | 0/7 [00:00<?, ?it/s]
# Rocket Mortgage Fieldhouse:  14%|█▍        | 1/7 [00:00<00:00,  7.10it/s]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 2/3 [00:01<00:00,  1.46it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 3/3 [00:02<00:00,  1.04it/s]
#
#
# Rocket Mortgage Fieldhouse:  29%|██▊       | 2/7 [00:04<00:12,  2.56s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Rocket Mortgage Fieldhouse:  43%|████▎     | 3/7 [00:07<00:10,  2.61s/it]
# Rocket Mortgage Fieldhouse:  57%|█████▋    | 4/7 [00:08<00:06,  2.11s/it]
# Rocket Mortgage Fieldhouse:  71%|███████▏  | 5/7 [00:09<00:03,  1.82s/it]
# Rocket Mortgage Fieldhouse:  86%|████████▌ | 6/7 [00:11<00:01,  1.65s/it]
# Rocket Mortgage Fieldhouse: 100%|██████████| 7/7 [00:12<00:00,  1.54s/it]
# Venues:  20%|██        | 6/30 [03:33<13:01, 32.57s/it]
# American Airlines Center:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.52it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
#
#
# American Airlines Center:  14%|█▍        | 1/7 [00:02<00:16,  2.82s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  29%|██▊       | 2/7 [00:01<00:03,  1.50it/s]
#
# Pages 2025-11-01→2025-11-30:  43%|████▎     | 3/7 [00:02<00:03,  1.07it/s]
#
# Pages 2025-11-01→2025-11-30:  57%|█████▋    | 4/7 [00:03<00:03,  1.08s/it]
#
# Pages 2025-11-01→2025-11-30:  71%|███████▏  | 5/7 [00:05<00:02,  1.17s/it]
#
# Pages 2025-11-01→2025-11-30:  86%|████████▌ | 6/7 [00:06<00:01,  1.23s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 7/7 [00:07<00:00,  1.25s/it]
#
#
# American Airlines Center:  29%|██▊       | 2/7 [00:12<00:34,  6.81s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  50%|█████     | 2/4 [00:01<00:01,  1.53it/s]
#
# Pages 2025-12-01→2025-12-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.06it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 4/4 [00:03<00:00,  1.09s/it]
#
#
# American Airlines Center:  43%|████▎     | 3/7 [00:17<00:24,  6.14s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.53it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 3/3 [00:02<00:00,  1.07it/s]
#
#
# American Airlines Center:  57%|█████▋    | 4/7 [00:21<00:15,  5.29s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# American Airlines Center:  71%|███████▏  | 5/7 [00:24<00:08,  4.33s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.51it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 3/3 [00:02<00:00,  1.07it/s]
#
#
# American Airlines Center:  86%|████████▌ | 6/7 [00:28<00:04,  4.21s/it]
#
# Pages 2026-04-01→2026-04-12:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-04-01→2026-04-12: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
#
#
# American Airlines Center: 100%|██████████| 7/7 [00:30<00:00,  3.69s/it]
# Venues:  23%|██▎       | 7/30 [04:05<12:26, 32.45s/it]
# Ball Arena:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.50it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 3/3 [00:02<00:00,  1.07it/s]
#
#
# Ball Arena:  14%|█▍        | 1/7 [00:02<00:17,  3.00s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  29%|██▊       | 2/7 [00:01<00:03,  1.30it/s]
#
# Pages 2025-11-01→2025-11-30:  43%|████▎     | 3/7 [00:02<00:04,  1.01s/it]
#
# Pages 2025-11-01→2025-11-30:  57%|█████▋    | 4/7 [00:04<00:03,  1.14s/it]
#
# Pages 2025-11-01→2025-11-30:  71%|███████▏  | 5/7 [00:05<00:02,  1.21s/it]
#
# Pages 2025-11-01→2025-11-30:  86%|████████▌ | 6/7 [00:06<00:01,  1.25s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it]
#
#
# Ball Arena:  29%|██▊       | 2/7 [00:12<00:34,  6.99s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  50%|█████     | 2/4 [00:01<00:01,  1.49it/s]
#
# Pages 2025-12-01→2025-12-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.03it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 4/4 [00:04<00:00,  1.09s/it]
#
#
# Ball Arena:  43%|████▎     | 3/7 [00:18<00:25,  6.35s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.52it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
#
#
# Ball Arena:  57%|█████▋    | 4/7 [00:22<00:16,  5.43s/it]
# Ball Arena:  71%|███████▏  | 5/7 [00:23<00:07,  3.95s/it]
# Ball Arena:  86%|████████▌ | 6/7 [00:25<00:03,  3.06s/it]
# Ball Arena: 100%|██████████| 7/7 [00:26<00:00,  2.49s/it]
# Venues:  27%|██▋       | 8/30 [04:33<11:19, 30.90s/it]
# Little Caesars Arena:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# Little Caesars Arena:  14%|█▍        | 1/7 [00:01<00:08,  1.48s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  40%|████      | 2/5 [00:01<00:02,  1.50it/s]
#
# Pages 2025-11-01→2025-11-30:  60%|██████    | 3/5 [00:02<00:01,  1.05it/s]
#
# Pages 2025-11-01→2025-11-30:  80%|████████  | 4/5 [00:04<00:01,  1.10s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 5/5 [00:05<00:00,  1.17s/it]
#
#
# Little Caesars Arena:  29%|██▊       | 2/7 [00:08<00:23,  4.67s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  50%|█████     | 2/4 [00:01<00:01,  1.47it/s]
#
# Pages 2025-12-01→2025-12-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.05it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 4/4 [00:03<00:00,  1.08s/it]
#
#
# Little Caesars Arena:  43%|████▎     | 3/7 [00:13<00:20,  5.06s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# Little Caesars Arena:  57%|█████▋    | 4/7 [00:16<00:12,  4.14s/it]
# Little Caesars Arena:  71%|███████▏  | 5/7 [00:17<00:06,  3.13s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Little Caesars Arena:  86%|████████▌ | 6/7 [00:20<00:02,  2.97s/it]
#
# Pages 2026-04-01→2026-04-12:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-04-01→2026-04-12: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
#
#
# Little Caesars Arena: 100%|██████████| 7/7 [00:23<00:00,  2.86s/it]
# Venues:  30%|███       | 9/30 [04:57<10:06, 28.89s/it]
# Chase Center:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.51it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 3/3 [00:02<00:00,  1.02it/s]
#
#
# Chase Center:  14%|█▍        | 1/7 [00:02<00:17,  2.91s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  29%|██▊       | 2/7 [00:01<00:03,  1.48it/s]
#
# Pages 2025-11-01→2025-11-30:  43%|████▎     | 3/7 [00:02<00:03,  1.05it/s]
#
# Pages 2025-11-01→2025-11-30:  57%|█████▋    | 4/7 [00:04<00:03,  1.11s/it]
#
# Pages 2025-11-01→2025-11-30:  71%|███████▏  | 5/7 [00:05<00:02,  1.25s/it]
#
# Pages 2025-11-01→2025-11-30:  86%|████████▌ | 6/7 [00:06<00:01,  1.28s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 7/7 [00:08<00:00,  1.30s/it]
#
#
# Chase Center:  29%|██▊       | 2/7 [00:12<00:34,  6.93s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  50%|█████     | 2/4 [00:01<00:01,  1.48it/s]
#
# Pages 2025-12-01→2025-12-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.05it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 4/4 [00:04<00:00,  1.09s/it]
#
#
# Chase Center:  43%|████▎     | 3/7 [00:18<00:24,  6.22s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Chase Center:  57%|█████▋    | 4/7 [00:20<00:14,  4.81s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s]
#
#
# Chase Center:  71%|███████▏  | 5/7 [00:23<00:08,  4.05s/it]
# Chase Center:  86%|████████▌ | 6/7 [00:24<00:03,  3.13s/it]
# Chase Center: 100%|██████████| 7/7 [00:26<00:00,  2.53s/it]
# Venues:  33%|███▎      | 10/30 [05:24<09:27, 28.38s/it]
# Toyota Center:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 2/2 [00:01<00:00,  1.50it/s]
#
#
# Toyota Center:  14%|█▍        | 1/7 [00:01<00:08,  1.49s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  33%|███▎      | 2/6 [00:01<00:02,  1.50it/s]
#
# Pages 2025-11-01→2025-11-30:  50%|█████     | 3/6 [00:02<00:02,  1.07it/s]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 4/6 [00:04<00:02,  1.17s/it]
#
# Pages 2025-11-01→2025-11-30:  83%|████████▎ | 5/6 [00:05<00:01,  1.23s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 6/6 [00:06<00:00,  1.26s/it]
#
#
# Toyota Center:  29%|██▊       | 2/7 [00:09<00:27,  5.55s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  50%|█████     | 2/4 [00:01<00:01,  1.49it/s]
#
# Pages 2025-12-01→2025-12-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.05it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 4/4 [00:03<00:00,  1.08s/it]
#
#
# Toyota Center:  43%|████▎     | 3/7 [00:15<00:21,  5.46s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.45it/s]
#
#
# Toyota Center:  57%|█████▋    | 4/7 [00:17<00:13,  4.38s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Toyota Center:  71%|███████▏  | 5/7 [00:20<00:07,  3.76s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.51it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
#
#
# Toyota Center:  86%|████████▌ | 6/7 [00:24<00:03,  3.83s/it]
# Toyota Center: 100%|██████████| 7/7 [00:25<00:00,  3.01s/it]
# Venues:  37%|███▋      | 11/30 [05:51<08:51, 27.99s/it]
# Gainbridge Fieldhouse:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# Gainbridge Fieldhouse:  14%|█▍        | 1/7 [00:01<00:08,  1.47s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  50%|█████     | 2/4 [00:01<00:01,  1.50it/s]
#
# Pages 2025-11-01→2025-11-30:  75%|███████▌  | 3/4 [00:02<00:00,  1.05it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
#
#
# Gainbridge Fieldhouse:  29%|██▊       | 2/7 [00:07<00:19,  3.90s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  50%|█████     | 2/4 [00:01<00:01,  1.50it/s]
#
# Pages 2025-12-01→2025-12-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.06it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 4/4 [00:03<00:00,  1.08s/it]
#
#
# Gainbridge Fieldhouse:  43%|████▎     | 3/7 [00:12<00:18,  4.56s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s]
#
#
# Gainbridge Fieldhouse:  57%|█████▋    | 4/7 [00:15<00:11,  3.84s/it]
# Gainbridge Fieldhouse:  71%|███████▏  | 5/7 [00:16<00:05,  2.96s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# Gainbridge Fieldhouse:  86%|████████▌ | 6/7 [00:19<00:02,  2.87s/it]
# Gainbridge Fieldhouse: 100%|██████████| 7/7 [00:20<00:00,  2.36s/it]
# Venues:  40%|████      | 12/30 [06:13<07:49, 26.10s/it]
# Intuit Dome:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 2/2 [00:01<00:00,  1.43it/s]
#
#
# Intuit Dome:  14%|█▍        | 1/7 [00:01<00:09,  1.55s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  40%|████      | 2/5 [00:01<00:01,  1.53it/s]
#
# Pages 2025-11-01→2025-11-30:  60%|██████    | 3/5 [00:02<00:01,  1.07it/s]
#
# Pages 2025-11-01→2025-11-30:  80%|████████  | 4/5 [00:03<00:01,  1.09s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 5/5 [00:05<00:00,  1.17s/it]
#
#
# Intuit Dome:  29%|██▊       | 2/7 [00:08<00:22,  4.55s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 2/2 [00:01<00:00,  1.55it/s]
#
#
# Intuit Dome:  43%|████▎     | 3/7 [00:10<00:14,  3.67s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
#
#
# Intuit Dome:  57%|█████▋    | 4/7 [00:13<00:09,  3.29s/it]
# Intuit Dome:  71%|███████▏  | 5/7 [00:14<00:05,  2.57s/it]
# Intuit Dome:  86%|████████▌ | 6/7 [00:16<00:02,  2.17s/it]
# Intuit Dome: 100%|██████████| 7/7 [00:17<00:00,  1.89s/it]
# Venues:  43%|████▎     | 13/30 [06:32<06:45, 23.87s/it]
# Crypto.com Arena:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  50%|█████     | 2/4 [00:01<00:01,  1.48it/s]
#
# Pages 2025-10-21→2025-10-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.03it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 4/4 [00:04<00:00,  1.10s/it]
#
#
# Crypto.com Arena:  14%|█▍        | 1/7 [00:04<00:25,  4.23s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/9 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  22%|██▏       | 2/9 [00:01<00:05,  1.24it/s]
#
# Pages 2025-11-01→2025-11-30:  33%|███▎      | 3/9 [00:03<00:06,  1.10s/it]
#
# Pages 2025-11-01→2025-11-30:  44%|████▍     | 4/9 [00:04<00:06,  1.26s/it]
#
# Pages 2025-11-01→2025-11-30:  56%|█████▌    | 5/9 [00:06<00:05,  1.29s/it]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 6/9 [00:07<00:03,  1.31s/it]
#
# Pages 2025-11-01→2025-11-30:  78%|███████▊  | 7/9 [00:08<00:02,  1.31s/it]
#
# Pages 2025-11-01→2025-11-30:  89%|████████▉ | 8/9 [00:09<00:01,  1.31s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 9/9 [00:11<00:00,  1.32s/it]
#
#
# Crypto.com Arena:  29%|██▊       | 2/7 [00:17<00:46,  9.33s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  33%|███▎      | 2/6 [00:01<00:02,  1.47it/s]
#
# Pages 2025-12-01→2025-12-31:  50%|█████     | 3/6 [00:02<00:02,  1.06it/s]
#
# Pages 2025-12-01→2025-12-31:  67%|██████▋   | 4/6 [00:04<00:02,  1.09s/it]
#
# Pages 2025-12-01→2025-12-31:  83%|████████▎ | 5/6 [00:05<00:01,  1.18s/it]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 6/6 [00:06<00:00,  1.22s/it]
#
#
# Crypto.com Arena:  43%|████▎     | 3/7 [00:25<00:35,  8.81s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
#
#
# Crypto.com Arena:  57%|█████▋    | 4/7 [00:28<00:19,  6.39s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
#
#
# Crypto.com Arena:  71%|███████▏  | 5/7 [00:30<00:10,  5.05s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# Crypto.com Arena:  86%|████████▌ | 6/7 [00:33<00:04,  4.24s/it]
# Crypto.com Arena: 100%|██████████| 7/7 [00:34<00:00,  3.29s/it]
# Venues:  47%|████▋     | 14/30 [07:08<07:19, 27.50s/it]
# FedExForum:   0%|          | 0/7 [00:00<?, ?it/s]
# FedExForum:  14%|█▍        | 1/7 [00:00<00:01,  5.53it/s]
# FedExForum:  29%|██▊       | 2/7 [00:01<00:04,  1.16it/s]
# FedExForum:  43%|████▎     | 3/7 [00:02<00:04,  1.09s/it]
# FedExForum:  57%|█████▋    | 4/7 [00:04<00:03,  1.17s/it]
# FedExForum:  71%|███████▏  | 5/7 [00:05<00:02,  1.22s/it]
# FedExForum:  86%|████████▌ | 6/7 [00:06<00:01,  1.25s/it]
# FedExForum: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it]
# Venues:  50%|█████     | 15/30 [07:17<05:30, 22.02s/it]
# Kaseya Center:   0%|          | 0/7 [00:00<?, ?it/s]
# Kaseya Center:  14%|█▍        | 1/7 [00:00<00:00,  7.99it/s]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Kaseya Center:  29%|██▊       | 2/7 [00:02<00:08,  1.62s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.51it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 3/3 [00:02<00:00,  1.07it/s]
#
#
# Kaseya Center:  43%|████▎     | 3/7 [00:06<00:10,  2.71s/it]
# Kaseya Center:  57%|█████▋    | 4/7 [00:08<00:06,  2.16s/it]
# Kaseya Center:  71%|███████▏  | 5/7 [00:09<00:03,  1.87s/it]
# Kaseya Center:  86%|████████▌ | 6/7 [00:10<00:01,  1.70s/it]
# Kaseya Center: 100%|██████████| 7/7 [00:12<00:00,  1.57s/it]
# Venues:  53%|█████▎    | 16/30 [07:30<04:31, 19.41s/it]
# Fiserv Forum:   0%|          | 0/7 [00:00<?, ?it/s]
# Fiserv Forum:  14%|█▍        | 1/7 [00:00<00:00,  7.57it/s]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 2/3 [00:01<00:00,  1.47it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
#
#
# Fiserv Forum:  29%|██▊       | 2/7 [00:04<00:12,  2.44s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 2/2 [00:01<00:00,  1.49it/s]
#
#
# Fiserv Forum:  43%|████▎     | 3/7 [00:06<00:10,  2.55s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.44it/s]
#
#
# Fiserv Forum:  57%|█████▋    | 4/7 [00:09<00:07,  2.62s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
#
#
# Fiserv Forum:  71%|███████▏  | 5/7 [00:12<00:05,  2.65s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
#
#
# Fiserv Forum:  86%|████████▌ | 6/7 [00:14<00:02,  2.65s/it]
# Fiserv Forum: 100%|██████████| 7/7 [00:16<00:00,  2.21s/it]
# Venues:  57%|█████▋    | 17/30 [07:48<04:04, 18.83s/it]
# Target Center:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s]
#
#
# Target Center:  14%|█▍        | 1/7 [00:01<00:09,  1.55s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  40%|████      | 2/5 [00:01<00:02,  1.47it/s]
#
# Pages 2025-11-01→2025-11-30:  60%|██████    | 3/5 [00:02<00:01,  1.04it/s]
#
# Pages 2025-11-01→2025-11-30:  80%|████████  | 4/5 [00:04<00:01,  1.12s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it]
#
#
# Target Center:  29%|██▊       | 2/7 [00:08<00:23,  4.74s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.49it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
#
#
# Target Center:  43%|████▎     | 3/7 [00:12<00:17,  4.42s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.46it/s]
#
#
# Target Center:  57%|█████▋    | 4/7 [00:15<00:11,  3.75s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Target Center:  71%|███████▏  | 5/7 [00:17<00:06,  3.37s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.52it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 3/3 [00:02<00:00,  1.07it/s]
#
#
# Target Center:  86%|████████▌ | 6/7 [00:21<00:03,  3.58s/it]
# Target Center: 100%|██████████| 7/7 [00:23<00:00,  2.83s/it]
# Venues:  60%|██████    | 18/30 [08:12<04:06, 20.53s/it]
# Smoothie King Center:   0%|          | 0/7 [00:00<?, ?it/s]
# Smoothie King Center:  14%|█▍        | 1/7 [00:00<00:00,  6.31it/s]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 2/3 [00:01<00:00,  1.48it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 3/3 [00:02<00:00,  1.05it/s]
#
#
# Smoothie King Center:  29%|██▊       | 2/7 [00:04<00:12,  2.45s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.50it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 3/3 [00:02<00:00,  1.07it/s]
#
#
# Smoothie King Center:  43%|████▎     | 3/7 [00:08<00:12,  3.17s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Smoothie King Center:  57%|█████▋    | 4/7 [00:10<00:08,  2.96s/it]
# Smoothie King Center:  71%|███████▏  | 5/7 [00:12<00:04,  2.37s/it]
# Smoothie King Center:  86%|████████▌ | 6/7 [00:13<00:02,  2.01s/it]
# Smoothie King Center: 100%|██████████| 7/7 [00:14<00:00,  1.78s/it]
# Venues:  63%|██████▎   | 19/30 [08:28<03:30, 19.18s/it]
#
# Venues:  63%|██████▎   | 19/30 [08:29<03:30, 19.18s/it]
# Madison Square Garden:   0%|          | 0/7 [00:00<?, ?it/s]
# Splitting 2025-10-21 → 2025-10-31 into weekly chunks...
# Venues:  63%|██████▎   | 19/30 [09:07<03:30, 19.18s/it]
#
# Venues:  63%|██████▎   | 19/30 [09:07<03:30, 19.18s/it]
# Madison Square Garden:  14%|█▍        | 1/7 [00:38<03:45, 37.53s/it]
# Splitting 2025-11-01 → 2025-11-30 into weekly chunks...
# 429 rate limit — sleeping 1.5s...
# Venues:  63%|██████▎   | 19/30 [10:59<03:30, 19.18s/it]
# Madison Square Garden:  29%|██▊       | 2/7 [02:30<06:45, 81.01s/it]
# Splitting 2025-12-01 → 2025-12-31 into weekly chunks...
# Venues:  63%|██████▎   | 19/30 [12:36<03:30, 19.18s/it]
# Madison Square Garden:  43%|████▎     | 3/7 [04:07<05:53, 88.35s/it]
# Splitting 2026-01-01 → 2026-01-31 into weekly chunks...
# Venues:  63%|██████▎   | 19/30 [13:41<03:30, 19.18s/it]
# Madison Square Garden:  57%|█████▋    | 4/7 [05:12<03:57, 79.04s/it]
# Splitting 2026-02-01 → 2026-02-28 into weekly chunks...
# Venues:  63%|██████▎   | 19/30 [14:23<03:30, 19.18s/it]
# Madison Square Garden:  71%|███████▏  | 5/7 [05:54<02:11, 65.68s/it]
# Splitting 2026-03-01 → 2026-03-31 into weekly chunks...
# Madison Square Garden:  86%|████████▌ | 6/7 [06:27<00:55, 55.21s/it]
#
# Pages 2026-04-01→2026-04-12:   0%|          | 0/8 [00:00<?, ?it/s]
#
# Pages 2026-04-01→2026-04-12:  25%|██▌       | 2/8 [00:01<00:04,  1.49it/s]
#
# Pages 2026-04-01→2026-04-12:  38%|███▊      | 3/8 [00:02<00:04,  1.03it/s]
#
# Pages 2026-04-01→2026-04-12:  50%|█████     | 4/8 [00:04<00:04,  1.11s/it]
#
# Pages 2026-04-01→2026-04-12:  62%|██████▎   | 5/8 [00:05<00:03,  1.19s/it]
#
# Pages 2026-04-01→2026-04-12:  75%|███████▌  | 6/8 [00:06<00:02,  1.25s/it]
#
# Pages 2026-04-01→2026-04-12:  88%|████████▊ | 7/8 [00:08<00:01,  1.27s/it]
#
# Pages 2026-04-01→2026-04-12: 100%|██████████| 8/8 [00:09<00:00,  1.29s/it]
#
#
# Madison Square Garden: 100%|██████████| 7/7 [06:38<00:00, 40.68s/it]
# Venues:  67%|██████▋   | 20/30 [15:08<22:14, 133.42s/it]
# Paycom Center:   0%|          | 0/7 [00:00<?, ?it/s]
# Paycom Center:  14%|█▍        | 1/7 [00:00<00:00,  7.90it/s]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# Paycom Center:  29%|██▊       | 2/7 [00:02<00:08,  1.63s/it]
# Paycom Center:  43%|████▎     | 3/7 [00:04<00:06,  1.51s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
#
#
# Paycom Center:  57%|█████▋    | 4/7 [00:06<00:05,  1.98s/it]
# Paycom Center:  71%|███████▏  | 5/7 [00:08<00:03,  1.75s/it]
# Paycom Center:  86%|████████▌ | 6/7 [00:09<00:01,  1.61s/it]
# Paycom Center: 100%|██████████| 7/7 [00:10<00:00,  1.51s/it]
# Venues:  70%|███████   | 21/30 [15:20<14:32, 97.00s/it]
# Kia Center:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Kia Center:  14%|█▍        | 1/7 [00:01<00:09,  1.53s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 2/3 [00:01<00:00,  1.49it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 3/3 [00:02<00:00,  1.04it/s]
#
#
# Kia Center:  29%|██▊       | 2/7 [00:05<00:15,  3.02s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.49it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 3/3 [00:02<00:00,  1.07it/s]
#
#
# Kia Center:  43%|████▎     | 3/7 [00:09<00:13,  3.46s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
#
#
# Kia Center:  57%|█████▋    | 4/7 [00:12<00:09,  3.15s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Kia Center:  71%|███████▏  | 5/7 [00:14<00:05,  2.97s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 2/2 [00:01<00:00,  1.50it/s]
#
#
# Kia Center:  86%|████████▌ | 6/7 [00:17<00:02,  2.93s/it]
# Kia Center: 100%|██████████| 7/7 [00:19<00:00,  2.40s/it]
# Venues:  73%|███████▎  | 22/30 [15:40<09:51, 73.97s/it]
# Xfinity Mobile Arena:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  50%|█████     | 2/4 [00:01<00:01,  1.44it/s]
#
# Pages 2025-10-21→2025-10-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.04it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 4/4 [00:04<00:00,  1.09s/it]
#
#
# Xfinity Mobile Arena:  14%|█▍        | 1/7 [00:04<00:25,  4.17s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/8 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  25%|██▌       | 2/8 [00:01<00:03,  1.52it/s]
#
# Pages 2025-11-01→2025-11-30:  38%|███▊      | 3/8 [00:02<00:04,  1.06it/s]
#
# Pages 2025-11-01→2025-11-30:  50%|█████     | 4/8 [00:04<00:04,  1.09s/it]
#
# Pages 2025-11-01→2025-11-30:  62%|██████▎   | 5/8 [00:05<00:03,  1.18s/it]
#
# Pages 2025-11-01→2025-11-30:  75%|███████▌  | 6/8 [00:06<00:02,  1.29s/it]
#
# Pages 2025-11-01→2025-11-30:  88%|████████▊ | 7/8 [00:08<00:01,  1.31s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 8/8 [00:09<00:00,  1.33s/it]
#
#
# Xfinity Mobile Arena:  29%|██▊       | 2/7 [00:15<00:40,  8.15s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  29%|██▊       | 2/7 [00:01<00:03,  1.46it/s]
#
# Pages 2025-12-01→2025-12-31:  43%|████▎     | 3/7 [00:02<00:03,  1.05it/s]
#
# Pages 2025-12-01→2025-12-31:  57%|█████▋    | 4/7 [00:04<00:03,  1.09s/it]
#
# Pages 2025-12-01→2025-12-31:  71%|███████▏  | 5/7 [00:05<00:02,  1.19s/it]
#
# Pages 2025-12-01→2025-12-31:  86%|████████▌ | 6/7 [00:06<00:01,  1.25s/it]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it]
#
#
# Xfinity Mobile Arena:  43%|████▎     | 3/7 [00:24<00:34,  8.72s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31:  40%|████      | 2/5 [00:01<00:01,  1.51it/s]
#
# Pages 2026-01-01→2026-01-31:  60%|██████    | 3/5 [00:02<00:01,  1.06it/s]
#
# Pages 2026-01-01→2026-01-31:  80%|████████  | 4/5 [00:03<00:01,  1.08s/it]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
#
#
# Xfinity Mobile Arena:  57%|█████▋    | 4/7 [00:31<00:23,  7.89s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# Xfinity Mobile Arena:  71%|███████▏  | 5/7 [00:33<00:11,  6.00s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31:  50%|█████     | 2/4 [00:01<00:01,  1.53it/s]
#
# Pages 2026-03-01→2026-03-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.07it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 4/4 [00:03<00:00,  1.08s/it]
#
#
# Xfinity Mobile Arena:  86%|████████▌ | 6/7 [00:39<00:05,  5.76s/it]
# Xfinity Mobile Arena: 100%|██████████| 7/7 [00:40<00:00,  4.31s/it]
# Venues:  77%|███████▋  | 23/30 [16:22<07:29, 64.26s/it]
# PHX Arena:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# PHX Arena:  14%|█▍        | 1/7 [00:01<00:09,  1.51s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  33%|███▎      | 2/6 [00:01<00:02,  1.41it/s]
#
# Pages 2025-11-01→2025-11-30:  50%|█████     | 3/6 [00:02<00:02,  1.02it/s]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 4/6 [00:04<00:02,  1.12s/it]
#
# Pages 2025-11-01→2025-11-30:  83%|████████▎ | 5/6 [00:05<00:01,  1.19s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 6/6 [00:06<00:00,  1.23s/it]
#
#
# PHX Arena:  29%|██▊       | 2/7 [00:09<00:27,  5.42s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  50%|█████     | 2/4 [00:01<00:01,  1.51it/s]
#
# Pages 2025-12-01→2025-12-31:  75%|███████▌  | 3/4 [00:02<00:00,  1.06it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 4/4 [00:03<00:00,  1.08s/it]
#
#
# PHX Arena:  43%|████▎     | 3/7 [00:15<00:21,  5.39s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
#
#
# PHX Arena:  57%|█████▋    | 4/7 [00:17<00:12,  4.31s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# PHX Arena:  71%|███████▏  | 5/7 [00:20<00:07,  3.71s/it]
# PHX Arena:  86%|████████▌ | 6/7 [00:21<00:02,  2.90s/it]
# PHX Arena: 100%|██████████| 7/7 [00:22<00:00,  2.39s/it]
# Venues:  80%|████████  | 24/30 [16:46<05:13, 52.23s/it]
# Moda Center:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s]
#
#
# Moda Center:  14%|█▍        | 1/7 [00:01<00:08,  1.48s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  50%|█████     | 2/4 [00:01<00:01,  1.46it/s]
#
# Pages 2025-11-01→2025-11-30:  75%|███████▌  | 3/4 [00:02<00:00,  1.05it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 4/4 [00:04<00:00,  1.10s/it]
#
#
# Moda Center:  29%|██▊       | 2/7 [00:06<00:18,  3.79s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
#
#
# Moda Center:  43%|████▎     | 3/7 [00:09<00:13,  3.27s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
#
#
# Moda Center:  57%|█████▋    | 4/7 [00:12<00:09,  3.03s/it]
# Moda Center:  71%|███████▏  | 5/7 [00:13<00:04,  2.42s/it]
# Moda Center:  86%|████████▌ | 6/7 [00:14<00:02,  2.05s/it]
# Moda Center: 100%|██████████| 7/7 [00:16<00:00,  1.81s/it]
# Venues:  83%|████████▎ | 25/30 [17:04<03:28, 41.78s/it]
# Golden 1 Center:   0%|          | 0/7 [00:00<?, ?it/s]
# Golden 1 Center:  14%|█▍        | 1/7 [00:00<00:01,  5.90it/s]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 2/3 [00:01<00:00,  1.47it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
#
#
# Golden 1 Center:  29%|██▊       | 2/7 [00:04<00:12,  2.56s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Golden 1 Center:  43%|████▎     | 3/7 [00:07<00:10,  2.61s/it]
# Golden 1 Center:  57%|█████▋    | 4/7 [00:08<00:06,  2.11s/it]
# Golden 1 Center:  71%|███████▏  | 5/7 [00:09<00:03,  1.83s/it]
# Golden 1 Center:  86%|████████▌ | 6/7 [00:11<00:01,  1.66s/it]
# Golden 1 Center: 100%|██████████| 7/7 [00:12<00:00,  1.55s/it]
# Venues:  87%|████████▋ | 26/30 [17:17<02:13, 33.33s/it]
# Frost Bank Center:   0%|          | 0/7 [00:00<?, ?it/s]
# Frost Bank Center:  14%|█▍        | 1/7 [00:00<00:00,  6.86it/s]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 2/3 [00:01<00:00,  1.48it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
#
#
# Frost Bank Center:  29%|██▊       | 2/7 [00:04<00:12,  2.42s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 2/2 [00:01<00:00,  1.51it/s]
#
#
# Frost Bank Center:  43%|████▎     | 3/7 [00:06<00:10,  2.53s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Frost Bank Center:  57%|█████▋    | 4/7 [00:09<00:07,  2.63s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28:  50%|█████     | 2/4 [00:01<00:01,  1.51it/s]
#
# Pages 2026-02-01→2026-02-28:  75%|███████▌  | 3/4 [00:02<00:00,  1.03it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 4/4 [00:04<00:00,  1.10s/it]
#
#
# Frost Bank Center:  71%|███████▏  | 5/7 [00:14<00:07,  3.63s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
#
#
# Frost Bank Center:  86%|████████▌ | 6/7 [00:17<00:03,  3.29s/it]
# Frost Bank Center: 100%|██████████| 7/7 [00:18<00:00,  2.66s/it]
# Venues:  90%|█████████ | 27/30 [17:37<01:28, 29.39s/it]
# Scotiabank Arena:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  33%|███▎      | 2/6 [00:01<00:02,  1.53it/s]
#
# Pages 2025-10-21→2025-10-31:  50%|█████     | 3/6 [00:02<00:02,  1.08it/s]
#
# Pages 2025-10-21→2025-10-31:  67%|██████▋   | 4/6 [00:03<00:02,  1.08s/it]
#
# Pages 2025-10-21→2025-10-31:  83%|████████▎ | 5/6 [00:05<00:01,  1.17s/it]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 6/6 [00:06<00:00,  1.22s/it]
#
#
# Scotiabank Arena:  14%|█▍        | 1/7 [00:06<00:40,  6.76s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  29%|██▊       | 2/7 [00:01<00:03,  1.49it/s]
#
# Pages 2025-11-01→2025-11-30:  43%|████▎     | 3/7 [00:02<00:03,  1.06it/s]
#
# Pages 2025-11-01→2025-11-30:  57%|█████▋    | 4/7 [00:03<00:03,  1.08s/it]
#
# Pages 2025-11-01→2025-11-30:  71%|███████▏  | 5/7 [00:05<00:02,  1.25s/it]
#
# Pages 2025-11-01→2025-11-30:  86%|████████▌ | 6/7 [00:07<00:01,  1.34s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 7/7 [00:08<00:00,  1.38s/it]
#
#
# Scotiabank Arena:  29%|██▊       | 2/7 [00:16<00:43,  8.61s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  40%|████      | 2/5 [00:01<00:02,  1.49it/s]
#
# Pages 2025-12-01→2025-12-31:  60%|██████    | 3/5 [00:02<00:01,  1.06it/s]
#
# Pages 2025-12-01→2025-12-31:  80%|████████  | 4/5 [00:04<00:01,  1.11s/it]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
#
#
# Scotiabank Arena:  43%|████▎     | 3/7 [00:23<00:30,  7.74s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.53it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
#
#
# Scotiabank Arena:  57%|█████▋    | 4/7 [00:27<00:18,  6.27s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.50it/s]
#
#
# Scotiabank Arena:  71%|███████▏  | 5/7 [00:30<00:09,  4.97s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.53it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 3/3 [00:02<00:00,  1.08it/s]
#
#
# Scotiabank Arena:  86%|████████▌ | 6/7 [00:34<00:04,  4.64s/it]
# Scotiabank Arena: 100%|██████████| 7/7 [00:35<00:00,  3.57s/it]
# Venues:  93%|█████████▎| 28/30 [18:14<01:03, 31.56s/it]
# Delta Center:   0%|          | 0/7 [00:00<?, ?it/s]
# Delta Center:  14%|█▍        | 1/7 [00:00<00:00,  7.62it/s]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 2/3 [00:01<00:00,  1.49it/s]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
#
#
# Delta Center:  29%|██▊       | 2/7 [00:04<00:12,  2.43s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
#
#
# Delta Center:  43%|████▎     | 3/7 [00:06<00:10,  2.56s/it]
# Delta Center:  57%|█████▋    | 4/7 [00:08<00:06,  2.06s/it]
# Delta Center:  71%|███████▏  | 5/7 [00:09<00:03,  1.80s/it]
# Delta Center:  86%|████████▌ | 6/7 [00:10<00:01,  1.63s/it]
# Delta Center: 100%|██████████| 7/7 [00:12<00:00,  1.53s/it]
# Venues:  97%|█████████▋| 29/30 [18:27<00:26, 26.10s/it]
# Capital One Arena:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2025-10-21→2025-10-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.47it/s]
#
# Pages 2025-10-21→2025-10-31: 100%|██████████| 3/3 [00:02<00:00,  1.04it/s]
#
#
# Capital One Arena:  14%|█▍        | 1/7 [00:02<00:17,  2.86s/it]
#
# Pages 2025-11-01→2025-11-30:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Pages 2025-11-01→2025-11-30:  33%|███▎      | 2/6 [00:01<00:02,  1.50it/s]
#
# Pages 2025-11-01→2025-11-30:  50%|█████     | 3/6 [00:02<00:02,  1.05it/s]
#
# Pages 2025-11-01→2025-11-30:  67%|██████▋   | 4/6 [00:04<00:02,  1.10s/it]
#
# Pages 2025-11-01→2025-11-30:  83%|████████▎ | 5/6 [00:05<00:01,  1.18s/it]
#
# Pages 2025-11-01→2025-11-30: 100%|██████████| 6/6 [00:06<00:00,  1.23s/it]
#
#
# Capital One Arena:  29%|██▊       | 2/7 [00:10<00:29,  5.91s/it]
#
# Pages 2025-12-01→2025-12-31:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Pages 2025-12-01→2025-12-31:  40%|████      | 2/5 [00:01<00:02,  1.49it/s]
#
# Pages 2025-12-01→2025-12-31:  60%|██████    | 3/5 [00:02<00:01,  1.05it/s]
#
# Pages 2025-12-01→2025-12-31:  80%|████████  | 4/5 [00:04<00:01,  1.09s/it]
#
# Pages 2025-12-01→2025-12-31: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
#
#
# Capital One Arena:  43%|████▎     | 3/7 [00:17<00:25,  6.29s/it]
#
# Pages 2026-01-01→2026-01-31:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Pages 2026-01-01→2026-01-31:  67%|██████▋   | 2/3 [00:01<00:00,  1.51it/s]
#
# Pages 2026-01-01→2026-01-31: 100%|██████████| 3/3 [00:02<00:00,  1.08it/s]
#
#
# Capital One Arena:  57%|█████▋    | 4/7 [00:21<00:16,  5.38s/it]
#
# Pages 2026-02-01→2026-02-28:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-02-01→2026-02-28: 100%|██████████| 2/2 [00:01<00:00,  1.49it/s]
#
#
# Capital One Arena:  71%|███████▏  | 5/7 [00:24<00:08,  4.41s/it]
#
# Pages 2026-03-01→2026-03-31:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-03-01→2026-03-31: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
#
#
# Capital One Arena:  86%|████████▌ | 6/7 [00:26<00:03,  3.81s/it]
#
# Pages 2026-04-01→2026-04-12:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Pages 2026-04-01→2026-04-12: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
#
#
# Capital One Arena: 100%|██████████| 7/7 [00:29<00:00,  3.43s/it]
# Venues: 100%|██████████| 30/30 [18:58<00:00, 37.96s/it]
# 35973

# %% [markdown]
# ### Cleaning

# %%
# Make sure 'date' is datetime
events_df['date'] = pd.to_datetime(events_df['date'])

# Define season range
season_start = pd.Timestamp("2025-10-21")
season_end   = pd.Timestamp("2026-04-12")

# Filter to events strictly inside the season
events_df = events_df[(events_df['date'] >= season_start) & (events_df['date'] <= season_end)]

# Optional: reset index
events_df = events_df.reset_index(drop=True)

events_df.head()
# Out:
#                                  name       date      time  \
# 0    Atlanta Hawks v. Toronto Raptors 2025-10-22  19:30:00
# 1  Atlanta Falcons vs. Miami Dolphins 2025-10-26  13:00:00
# 2    RICO NASTY: LETHAL NORTH AMERICA 2025-10-21  20:00:00
# 3                       James Vickery 2025-10-21  19:00:00
# 4                        Fear Factory 2025-10-21  19:00:00
#
#                         venue           team
# 0            State Farm Arena  Atlanta Hawks
# 1       Mercedes-Benz Stadium  Atlanta Hawks
# 2                  Tabernacle  Atlanta Hawks
# 3  The Masquerade - Purgatory  Atlanta Hawks
# 4       The Masquerade - Hell  Atlanta Hawks

# %%
events_df = pd.DataFrame(all_events)

# Filter out add-ons / packages
exclude_keywords = ["voucher", "suite pass", "post game", "item", "educator", "access only", "gift", "discount pass", "tour experience", ]
mask = ~events_df['name'].str.lower().apply(lambda x: any(kw in x for kw in exclude_keywords))
clean_events_df = (
    events_df[mask]
    .drop_duplicates(subset=["team", "date", "time", "venue"])
    .sort_values(["date", "time", "venue"])
    .reset_index(drop=True)
)

clean_events_df = clean_events_df[clean_events_df['venue'].isin(venue_info_df['Venue Name'])]
clean_events_df
# Out:
#                                          name        date      time  \
# 0                            Flyers 2024 ROFR  2025-04-15  19:00:00
# 1                        WWE Monday Night RAW  2025-10-20  16:30:00
# 3                      Playboi Carti - Suites  2025-10-20  19:00:00
# 12                           Boardroom Access  2025-10-20  19:00:00
# 14                       Billie Eilish Luxury  2025-10-20  19:00:00
# ...                                       ...         ...       ...
# 28019                  HEAT vs. Atlanta Hawks  2026-04-12  18:00:00
# 28021   New York Knicks vs. Charlotte Hornets  2026-04-12  18:00:00
# 28023        Toronto Raptors vs Brooklyn Nets  2026-04-12  18:00:00
# 28024        Boston Celtics vs. Orlando Magic  2026-04-12  18:00:00
# 28026  Philadelphia 76ers vs. Milwaukee Bucks  2026-04-12  18:00:00
#
#                        venue                team
# 0       Xfinity Mobile Arena  Philadelphia 76ers
# 1            Golden 1 Center    Sacramento Kings
# 3                 Ball Arena      Denver Nuggets
# 12     Madison Square Garden     New York Knicks
# 14           Spectrum Center   Charlotte Hornets
# ...                      ...                 ...
# 28019          Kaseya Center          Miami Heat
# 28021  Madison Square Garden     New York Knicks
# 28023       Scotiabank Arena     Toronto Raptors
# 28024              TD Garden      Boston Celtics
# 28026   Xfinity Mobile Arena  Philadelphia 76ers
#
# [2335 rows x 5 columns]

# %%
clean_events_df.to_csv('nba_events.csv', index=False)
